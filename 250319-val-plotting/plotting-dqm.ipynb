# %%
import ROOT

pts = ['pt1', 'pt10', 'pt100', 'pt1000']
geometries = ['current-geometry', 'iRPC-added-geometry', 'target-geometry']

pt = pts[3]

file1 = ROOT.TFile(f"dqm/DQM-{pt}-{geometries[0]}.root")
file2 = ROOT.TFile(f"dqm/DQM-{pt}-{geometries[1]}.root")
file3 = ROOT.TFile(f"dqm/DQM-{pt}-{geometries[2]}.root")

#hist_name = 'DQMData/Run 1/Muons/Run summary/RecoMuonV/MuonTrack/globalMuons/effic_vs_eta'
hist_name = 'DQMData/Run 1/Muons/Run summary/RecoMuonV/MuonTrack/standAloneMuons/effic_vs_eta'

hist1 = file1.Get(hist_name)
hist2 = file2.Get(hist_name)
hist3 = file3.Get(hist_name)

hist1.SetLineColor(ROOT.kBlack)
hist2.SetLineColor(ROOT.kBlue)
hist3.SetLineColor(ROOT.kRed)

hist1.SetLineWidth(1)
hist2.SetLineWidth(1)
hist3.SetLineWidth(1)

canvas = ROOT.TCanvas("canvas", "Histogram", 800, 600)

hist1.GetYaxis().SetRangeUser(0.58, 1.02)

hist1.Draw("HIST E1")
hist2.Draw("HIST E1 SAME")
hist3.Draw("HIST E1 SAME")

legend = ROOT.TLegend(0.55, 0.2, 0.85, 0.35)

#hist1.SetTitle("")

ptitle = ROOT.TPaveText(0.15, 0.2, 0.45, 0.35, "NDC")
ptitle.SetFillColor(0)
ptitle.SetBorderSize(1)

ptitle.AddText("StandAloneMuon Eff vs eta")
ptitle.AddText(f"SingleMu, pT: {pt[2:]} GeV")
ptitle.AddText("Events: 1,000,000")
ptitle.Draw()

ROOT.gStyle.SetOptStat(0)

legend.AddEntry(hist1, geometries[0], "l")
legend.AddEntry(hist2, geometries[1], "l")
legend.AddEntry(hist3, geometries[2], "l")
legend.Draw()

hist1.Print("Entries")
hist2.Print("Entries")
hist3.Print("Entries")

canvas.Update()
canvas.SaveAs(f"plot/{pt}-standalonemuon_effic-eta.png")
# Out:
# TH1.Print Name  = effic_vs_eta, Entries= 959566, Total sum= 42.6566
# TH1.Print Name  = effic_vs_eta, Entries= 959912, Total sum= 43.4235
# TH1.Print Name  = effic_vs_eta, Entries= 959770, Total sum= 42.4558
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# Info in <TCanvas::Print>: png file plot/pt1000-standalonemuon_effic-eta.png has been created
# <div id="root_plot_1742995232769" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1742995232769(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-3.12500004656613,"fY1":0.52499999590218,"fX2":3.12500004656613,"fY2":1.07500000409782,"fXtoAbsPixelk":398,"fXtoPixelk":398,"fXtoPixel":127.359998102188,"fYtoAbsPixelk":1117.99998760223,"fYtoPixelk":1117.99998760223,"fYtoPixel":-1039.99998450279,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-3.12500004656613,"fPixeltoXk":-3.12500004656613,"fPixeltoX":0.00785175891097018,"fAbsPixeltoYk":1.07500000409782,"fPixeltoYk":0.52499999590218,"fPixeltoY":-9.61538475866502e-4,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-2.5,"fUymin":0.58,"fUxmax":2.5,"fUymax":1.02,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"canvas","fTitle":"Histogram","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;113:173,173,125;114: ...

# %%
eras = ['2021', '2023', '2024', '2025']
geometries = ['current', 'target']

era = eras[0]

file1 = ROOT.TFile(f"dqm/DQM-{era}-{geometries[0]}.root")
file2 = ROOT.TFile(f"dqm/DQM-{era}-{geometries[1]}.root")

hist_name = 'DQMData/Run 1/Muons/Run summary/RecoMuonV/MuonTrack/globalMuons/effic_vs_eta'
#hist_name = 'DQMData/Run 1/Muons/Run summary/RecoMuonV/MuonTrack/standAloneMuons/effic_vs_eta'
#hist_name = 'DQMData/Run 1/Muons/Run summary/RecoMuonV/MuonTrack/standAloneMuons/effic_vs_eta'
#hist_name = 'DQMData/Run 1/Muons/Run summary/RecoMuonV/MuonTrack/globalMuons/effic_vs_pt'

hist1 = file1.Get(hist_name)
hist2 = file2.Get(hist_name)

hist1.SetLineColor(ROOT.kBlack)
hist2.SetLineColor(ROOT.kBlue)

hist1.SetLineWidth(1)
hist2.SetLineWidth(1)

canvas = ROOT.TCanvas("canvas", "Histogram", 800, 600)

#hist1.SetTitle(f"Global Muon Eff vs eta, pT: {pt[2:]} GeV, Events: 100000")
#hist1.GetXaxis().SetRange(1, hist1.GetNbinsX())

hist1.Draw("HIST E1")
hist2.Draw("HIST E1 SAME")

legend = ROOT.TLegend(0.4, 0.2, 0.6, 0.3)
legend.AddEntry(hist1, geometries[0], "l")
legend.AddEntry(hist2, geometries[1], "l")
legend.Draw()

hist1.Print("all")
hist2.Print("all")

canvas.Update()
# Out:
# TH1.Print Name  = effic_vs_eta, Entries= 1918862, Total sum= 44.1255
#  fSumw[0]=0, x=-2.55, error=0
#  fSumw[1]=0, x=-2.45, error=0
#  fSumw[2]=0.876873, x=-2.35, error=0.00164762
#  fSumw[3]=0.86153, x=-2.25, error=0.00172928
#  fSumw[4]=0.898813, x=-2.15, error=0.00150909
#  fSumw[5]=0.915938, x=-2.05, error=0.00138709
#  fSumw[6]=0.940219, x=-1.95, error=0.0011872
#  fSumw[7]=0.94838, x=-1.85, error=0.00110518
#  fSumw[8]=0.945538, x=-1.75, error=0.00113321
#  fSumw[9]=0.953942, x=-1.65, error=0.00104645
#  fSumw[10]=0.951603, x=-1.55, error=0.00107243
#  fSumw[11]=0.958151, x=-1.45, error=0.0010033
#  fSumw[12]=0.961309, x=-1.35, error=0.00096107
#  fSumw[13]=0.957734, x=-1.25, error=0.00100886
#  fSumw[14]=0.925481, x=-1.15, error=0.00131039
#  fSumw[15]=0.927865, x=-1.05, error=0.00129141
#  fSumw[16]=0.902003, x=-0.95, error=0.00148389
#  fSumw[17]=0.81662, x=-0.85, error=0.00194221
#  fSumw[18]=0.901547, x=-0.75, error=0.00148833
#  fSumw[19]=0.931278, x=-0.65, error=0.00126396
#  fSumw[20]=0.928222, x=-0.55, error=0.00129357
#  fSumw[21]=0.942992, x=-0.45, error=0.00115989
#  fSumw[22]=0.931282, x=-0.35, error=0.00126618
#  fSumw[23]=0.848582, x=-0.25, error=0.00179268
#  fSumw[24]=0.92782, x=-0.15, error=0.00129219
#  fSumw[25]=0.937489, x=-0.05, error=0.00121563
#  fSumw[26]=0.938926, x=0.05, error=0.00120249
#  fSumw[27]=0.933405, x=0.15, error=0.00124492
#  fSumw[28]=0.835526, x=0.25, error=0.00185394
#  fSumw[29]=0.919859, x=0.35, error=0.00135897
#  fSumw[30]=0.937961, x=0.45, error=0.00120675
#  fSumw[31]=0.926564, x=0.55, error=0.00130725
#  fSumw[32]=0.929056, x=0.65, error=0.00128269
#  fSumw[33]=0.900973, x=0.75, error=0.00149218
#  fSumw[34]=0.820575, x=0.85, error=0.0019258
#  fSumw[35]=0.90569, x=0.95, error=0.00145868
#  fSumw[36]=0.925074, x=1.05, error=0.00131418
#  fSumw[37]=0.91963, x=1.15, error=0.00135655
#  fSumw[38]=0.956904, x=1.25, error=0.00101827
#  fSumw[39]=0.959546, x=1.35, error=0.000981824
#  fSumw[40]=0.956645, x=1.45, error=0.00102039
#  fSumw[41]=0.946958, x=1.55, error=0.00111997
#  fSumw[42]=0.956957, x=1.65, error=0.00101321
#  fSumw[43]=0.946959, x=1.75, error=0.00111917
#  fSumw[44]=0.947756, x=1.85, error=0.00111147
#  fSumw[45]=0.931693, x=1.95, error=0.00126327
#  fSumw[46]=0.907392, x=2.05, error=0.00144909
#  fSumw[47]=0.891827, x=2.15, error=0.00155424
#  fSumw[48]=0.860326, x=2.25, error=0.00173556
#  fSumw[49]=0.87808, x=2.35, error=0.00164065
#  fSumw[50]=0, x=2.45, error=0
#  fSumw[51]=0, x=2.55, error=0
# TH1.Print Name  = effic_vs_eta, Entries= 1919488, Total sum= 44.1166
#  fSumw[0]=0, x=-2.55, error=0
#  fSumw[1]=0, x=-2.45, error=0
#  fSumw[2]=0.874574, x=-2.35, error=0.0016585
#  fSumw[3]=0.862382, x=-2.25, error=0.00172605
#  fSumw[4]=0.894312, x=-2.15, error=0.0015342
#  fSumw[5]=0.917708, x=-2.05, error=0.00137902
#  fSumw[6]=0.939016, x=-1.95, error=0.00119929
#  fSumw[7]=0.946347, x=-1.85, error=0.00112381
#  fSumw[8]=0.94706, x=-1.75, error=0.00111814
#  fSumw[9]=0.953685, x=-1.65, error=0.00105213
#  fSumw[10]=0.951831, x=-1.55, error=0.00107027
#  fSumw[11]=0.956909, x=-1.45, error=0.00101197
#  fSumw[12]=0.960274, x=-1.35, error=0.000976586
#  fSumw[13]=0.957891, x=-1.25, error=0.00100281
#  fSumw[14]=0.920919, x=-1.15, error=0.00134873
#  fSumw[15]=0.926246, x=-1.05, error=0.00130556
#  fSumw[16]=0.900856, x=-0.95, error=0.00149517
#  fSumw[17]=0.814093, x=-0.85, error=0.00195058
#  fSumw[18]=0.90275, x=-0.75, error=0.00148016
#  fSumw[19]=0.928966, x=-0.65, error=0.00128426
#  fSumw[20]=0.929121, x=-0.55, error=0.00127887
#  fSumw[21]=0.943719, x=-0.45, error=0.0011534
#  fSumw[22]=0.932361, x=-0.35, error=0.00125739
#  fSumw[23]=0.848381, x=-0.25, error=0.00179559
#  fSumw[24]=0.934011, x=-0.15, error=0.00124074
#  fSumw[25]=0.939882, x=-0.05, error=0.00119144
#  fSumw[26]=0.939832, x=0.05, error=0.0011919
#  fSumw[27]=0.934086, x=0.15, error=0.00124009
#  fSumw[28]=0.834319, x=0.25, error=0.00186139
#  fSumw[29]=0.917243, x=0.35, error=0.0013795
#  fSumw[30]=0.937633, x=0.45, error=0.00121024
#  fSumw[31]=0.929767, x=0.55, error=0.00127347
#  fSumw[32]=0.928291, x=0.65, error=0.00128988
#  fSumw[33]=0.90255, x=0.75, error=0.00148151
#  fSumw[34]=0.823847, x=0.85, error=0.00191006
#  fSumw[35]=0.905086, x=0.95, error=0.00146636
#  fSumw[36]=0.924449, x=1.05, error=0.00132009
#  fSumw[37]=0.917822, x=1.15, error=0.00137258
#  fSumw[38]=0.955447, x=1.25, error=0.00103018
#  fSumw[39]=0.956999, x=1.35, error=0.00101431
#  fSumw[40]=0.954451, x=1.45, error=0.00103911
#  fSumw[41]=0.948334, x=1.55, error=0.0011064
#  fSumw[42]=0.953936, x=1.65, error=0.00104942
#  fSumw[43]=0.947658, x=1.75, error=0.00111216
#  fSumw[44]=0.947019, x=1.85, error=0.00111715
#  fSumw[45]=0.933893, x=1.95, error=0.00124525
#  fSumw[46]=0.910934, x=2.05, error=0.00142935
#  fSumw[47]=0.890328, x=2.15, error=0.00155937
#  fSumw[48]=0.863361, x=2.25, error=0.00172088
#  fSumw[49]=0.876028, x=2.35, error=0.00165022
#  fSumw[50]=0, x=2.45, error=0
#  fSumw[51]=0, x=2.55, error=0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas
# <div id="root_plot_1742993743547" style="width: 800px; height: 600px; position: relative">
# </div>
#
# <script>
#
# function display_root_plot_1742993743547(Core) {
#    let obj = Core.parse({"_typename":"TCanvasWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":3,"fSnapshot":{"_typename":"TCanvas","fUniqueID":0,"fBits":3342344,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.1,"fRightMargin":0.1,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":-3.12500004656613,"fY1":-0.126297989473397,"fX2":3.12500004656613,"fY2":1.13668182998111,"fXtoAbsPixelk":398,"fXtoPixelk":398,"fXtoPixel":127.359998102188,"fYtoAbsPixelk":514.799996590614,"fYtoPixelk":514.799996590614,"fYtoPixel":-452.897181086435,"fUtoAbsPixelk":0,"fUtoPixelk":0,"fUtoPixel":796,"fVtoAbsPixelk":572,"fVtoPixelk":572,"fVtoPixel":-572,"fAbsPixeltoXk":-3.12500004656613,"fPixeltoXk":-3.12500004656613,"fPixeltoX":0.00785175891097018,"fAbsPixeltoYk":1.13668182998111,"fPixeltoYk":-0.126297989473397,"fPixeltoY":-0.00220800667736802,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":1,"fYUpNDC":1,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":-2.5,"fUymin":0,"fUxmax":2.5,"fUymax":1.01038384050771,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":false,"fGridy":false,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[],"opt":[]},"fExecs":null,"fName":"canvas","fTitle":"Histogram","fNumPaletteColor":0,"fNextPaletteColor":0,"fDISPLAY":"$DISPLAY","fDoubleBuffer":0,"fRetained":true,"fXsizeUser":0,"fYsizeUser":0,"fXsizeReal":20,"fYsizeReal":15,"fWindowTopX":0,"fWindowTopY":0,"fWindowWidth":0,"fWindowHeight":0,"fCw":796,"fCh":572,"fCatt":{"_typename":"TAttCanvas","fXBetween":2,"fYBetween":2,"fTitleFromTop":1.2,"fXdate":0.2,"fYdate":0.3,"fAdate":1},"kMoveOpaque":true,"kResizeOpaque":true,"fHighLightColor":2,"fBatch":true,"kShowEventStatus":false,"kAutoExec":true,"kMenuBar":true},"fActive":false,"fReadOnly":true,"fWithoutPrimitives":false,"fHasExecs":false,"fPrimitives":[{"_typename":"TWebSnapshot","fUniqueID":0,"fBits":0,"fObjectID":"","fOption":"","fKind":4,"fSnapshot":{"_typename":"TWebPainting","fUniqueID":0,"fBits":0,"fOper":"0:255,255,255;1:0,0,0;2:255,0,0;3:0,255,0;4:0,0,255;5:255,255,0;6:255,0,255;7:0,255,255;8:89,211,84;9:89,84,216;10:254,254,254;11:192,182,172;12:76,76,76;13:102,102,102;14:127,127,127;15:153,153,153;16:178,178,178;17:204,204,204;18:229,229,229;19:242,242,242;20:204,198,170;21:204,198,170;22:193,191,168;23:186,181,163;24:178,165,150;25:183,163,155;26:173,153,140;27:155,142,130;28:135,102,86;29:175,206,198;30:132,193,163;31:137,168,160;32:130,158,140;33:173,188,198;34:122,142,153;35:117,137,145;36:104,130,150;37:109,122,132;38:124,153,209;39:127,127,155;40:170,165,191;41:211,206,135;42:221,186,135;43:188,158,130;44:198,153,124;45:191,130,119;46:206,94,96;47:170,142,147;48:165,119,122;49:147,104,112;50:211,89,84;51:146,0,255;52:122,0,255;53:98,0,255;54:74,0,255;55:51,0,255;56:27,0,255;57:3,0,255;58:0,20,255;59:0,44,255;60:0,68,255;61:0,91,255;62:0,115,255;63:0,139,255;64:0,163,255;65:0,187,255;66:0,210,255;67:0,234,255;68:0,255,251;69:0,255,227;70:0,255,204;71:0,255,180;72:0,255,156;73:0,255,132;74:0,255,108;75:0,255,85;76:0,255,61;77:0,255,37;78:0,255,13;79:10,255,0;80:34,255,0;81:57,255,0;82:81,255,0;83:105,255,0;84:129,255,0;85:153,255,0;86:176,255,0;87:200,255,0;88:224,255,0;89:248,255,0;90:255,238,0;91:255,214,0;92:255,190,0;93:255,166,0;94:255,142,0;95:255,119,0;96:255,95,0;97:255,71,0;98:255,47,0;99:255,23,0;100:111,45,168;101:165,42,42;102:178,190,181;103:87,144,252;104:248,156,32;105:228,37,54;106:150,74,139;107:156,156,161;108:122,33,221;109:24,69,251;110:255,94,2;111:201,31,22;112:200,73,169;113:173 ...
